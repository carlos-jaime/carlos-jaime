# %%
import json

# %%
#! pip install genson
# Out:
# ...
#   Created wheel for genson: filename=genson-1.2.2-py2.py3-none-any.whl size=21266 sha256=022f04032435a3d5f531cb270845469794aad7ccd0a84ba89acf72c8745b4f1f
#   Stored in directory: c:\users\carlos.jaime\appdata\local\pip\cache\wheels\2e\34\be\0194d05d18bc4695b5c4969178790d535bdd23eabdb9d3b1e3
# Successfully built genson
# ...

# %%
json_file = r'C:\Users\carlos.jaime\airflow-docker\welle.json'

with open(json_file, encoding="utf8") as f:
  data = json.load(f)

print(data)
# Out:
# [{'_id': {'$oid': '5fc536b06c18a48f5d19c628'}, 'campaign_id': '5fc5094f6c18a48f5d19c625', 'name': 'unimarc 3x2', 'tag': '3x2', 'promotion_type': 'chainPromotion', 'partners_info': [{'id': 105039, 'name': 'Unimarc - Concepción', 'active': True}], 'products': [{'gtin': 'P-3x2-7801620852689', 'name': '3x2 Gaseosa Pepsi 350Cc (Lata)', 'active': True}, {'gtin': 'P-3x2-7801620014513', 'name': '3x2 Gaseosa Pepsi 1.5 L', 'active': True}, {'gtin': 'P-3x2-7801620855253', 'name': '3x2 Pepsi 250 Cc (Desechable)', 'active': True}, {'gtin': 'P-3x2-7801620014681', 'name': '3x2 Gaseosa Pepsi 2 L', 'active': True}, {'gtin': 'P-3x2-7801620017552', 'name': '3x2 Gaseosa Pepsi 3 L', 'active': True}, {'gtin': 'P-3x2-7801620075941', 'name': '3x2 Gaseosa Pepsi 500 Ml', 'active': True}, {'gtin': 'P-3x2-7801620004217', 'name': '3x2 Pepsi Light 310Cc (Lata)', 'active': True}], 'filters': {'available_days': [], 'from_hour': 0, 'to_hour': 2359}, 'active': False, 'is_deleted': False, 'exposition_date_from': {'$da
# ...

# %%
data.
